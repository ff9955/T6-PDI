# %% [markdown]
# This notebook just contains a few plots of the total energy and different electronic populations of a single X-SH trajectory, that was restarted at 2ps. There are no visible discontinuities in any of these plots after 2ps, so I think the restart files' initial conditions adequately follow on from the chosen final step of the trajectory.
#
# The populations' continuity after 2ps shows that the files are being truncated properly.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
CSS_traj50 = np.loadtxt('/scratch/fivanovic/X-SH/T6-PDI/production_runs/test_restart_files/traj50_CSS.txt')
XT_traj50 = np.loadtxt('/scratch/fivanovic/X-SH/T6-PDI/production_runs/test_restart_files/traj50_XT.txt')
INT_traj50 = np.loadtxt('/scratch/fivanovic/X-SH/T6-PDI/production_runs/test_restart_files/traj50_INT.txt')
A_INT_traj50 = np.loadtxt('/scratch/fivanovic/X-SH/T6-PDI/production_runs/test_restart_files/traj50_A_INT.txt')
population_sim_time = np.arange(0,len(XT_traj50))*0.05*5 #multiplying by 0.05 as each timestep is 0.05fs, multiplying by 5 as the coeff 
#files only print every 5 steps.

energy_array_traj50 = np.loadtxt('/scratch/fivanovic/X-SH/T6-PDI/production_runs/test_restart_files/traj50_energy_array.txt')

# %%
plt.plot(population_sim_time, INT_traj50, color = 'b')
plt.xlabel('Time /fs')
#plt.ylabel('Energy /Hartree')
plt.ylabel('Electronic Population')
# Out:
# Text(0, 0.5, 'Electronic Population')
